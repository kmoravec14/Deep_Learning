# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
df = pd.read_csv("../Resources/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# df.describe()
# df['AFFILIATION'].nunique()

# %%
# # importing sweetviz
# import sweetviz as sv

# #analyzing the dataset
# charity_report = sv.analyze(df)
# #display the report
# charity_report.show_html('Charity.html')

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = df.drop("EIN", 1)
# df = df.drop("NAME", 1)
# df = df.drop("SPECIAL_CONSIDERATIONS",1)
# df = df.drop("STATUS",1)
# Out:
# /var/folders/08/k5qj0k9j1dbgppb_7vzc5rnm0000gn/T/ipykernel_11676/2688074749.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop("EIN", 1)

# %%
# Look at NAME value counts for binning
name_counts = df['NAME'].value_counts()
#  How many name counts are greater than 5?
name_counts[name_counts>5]
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
#                                                    ...
# OLD OAK CLIFF CONSERVATION LEAGUE INC                 6
# AMERICAN NEPHROLOGY NURSES ASSOCIATION                6
# HUMBLE ISD EDUCATIONAL SUPPORT GROUPS INC             6
# PROFESSIONAL LOADMASTER ASSOCIATION                   6
# CBMC INC                                              6
# Name: NAME, Length: 354, dtype: int64

# %%
# Determine the number of unique values in each column.
name_counts.nunique()
# Out:
# 92

# %%
# Determine which values to replace if counts are less than or equal to 5.
names_to_replace = list(name_counts[name_counts <= 5].index)

# Replace in dataframe
for app in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(app,"Other")
    
# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 2>()
#       1 # Determine which values to replace if counts are less than or equal to 5.
# ----> 2 names_to_replace = list(name_counts[name_counts <= 5].index)
#       4 # Replace in dataframe
#       5 for app in names_to_replace:
#
# NameError: name 'name_counts' is not defined

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 # Look at APPLICATION_TYPE value counts for binning
# ----> 2 application_counts = application_df['APPLICATION_TYPE'].value_counts()
#       3 application_counts
#
# NameError: name 'application_df' is not defined

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Replace in dataframe

application_types_to_replace = ["T9","T13","T12","T2","T25","T14","T29","T15","T17"]
# application_types_to_replace = ["T9","T13","T12","T2","T25","T14","T29","T15","T17"]

for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# # Look at CLASSIFICATION value counts for binning
# classifications_val = df['CLASSIFICATION'].value_counts().values
# classifications_ind = df['CLASSIFICATION'].value_counts().index

# %%
# print(classifications_val)

# %%
# classifications_val[1]

# %%
# print(classifications_ind)

# %%
# len(classifications_ind)

# %%
# classification = []

# for i in range(0,71):
#         if classifications_val[i] < 1000:
#             k = classifications_ind[i]
#             classification.append(k)

# %%
# len(classification)

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE

# %%
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

# len = len(classifications_val)

# classifications_val = df['CLASSIFICATION'].value_counts().values
# classifications_ind = df['CLASSIFICATION'].value_counts().index

# classifications_to_replace = []

# for i in range(0,71):
#         if classifications_val[i] < 1000:
#             k = classifications_ind[i]
#             classification.append(k)

# classifications_to_replace = classifications[(classifications < 1000)].index

class_df = df['CLASSIFICATION'].value_counts()

classifications_to_replace = class_df[(class_df < 100)].index

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# import numpy as np
# df['ASK_AMT'] = np.log10(df['ASK_AMT'])

# %%
df
# Out:
#                                                     NAME APPLICATION_TYPE  \
# 0                           BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1                 AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2                     ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3                         SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4               GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
# ...                                                  ...              ...
# 34294              THE LIONS CLUB OF HONOLULU KAMEHAMEHA               T4
# 34295           INTERNATIONAL ASSOCIATION OF LIONS CLUBS               T4
# 34296                                PTA HAWAII CONGRESS               T3
# 34297  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...               T5
# 34298                           WATERHOUSE CHARITABLE TR               T3
#
#             AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0           Independent          C1000    ProductDev   Association       1
# 1           Independent          C2000  Preservation  Co-operative       1
# 2      CompanySponsored          C3000    ProductDev   Association       1
# 3      CompanySponsored          C2000  Preservation         Trust       1
# 4           Independent          C1000     Heathcare         Trust       1
# ...                 ...            ...           ...           ...     ...
# 34294       Independent          C1000    ProductDev   Association       1
# 34295  CompanySponsored          C3000    ProductDev   Association       1
# 34296  CompanySponsored          C2000  Preservation   Association       1
# 34297       Independent          C3000    ProductDev   Association       1
# 34298       Independent          C1000  Preservation  Co-operative       1
#
#           INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  IS_SUCCESSFUL
# 0                  0                      N      5000              1
# 1             1-9999                      N    108590              1
# 2                  0                      N      5000              0
# 3        10000-24999                      N      6692              1
# 4      100000-499999                      N    142590              1
# ...              ...                    ...       ...            ...
# 34294              0                      N      5000              0
# 34295              0                      N      5000              0
# 34296              0                      N      5000              0
# 34297              0                      N      5000              1
# 34298          1M-5M                      N  36500179              0
#
# [34299 rows x 11 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df = pd.get_dummies(df,drop_first = True)

# %%
list(df)
# Out:
# ['STATUS',
#  'ASK_AMT',
#  'IS_SUCCESSFUL',
#  'NAME_100 BLACK MEN OF AMERICA',
#  'NAME_100 BLACK MEN OF MEMPHIS INC',
#  'NAME_100 BLACK MEN OF WEST GEORGIA INC',
#  'NAME_1150 WEBSTER STREET INC',
#  'NAME_116TH CAVALRY REGIMENT CHAPTER OF THE US CAVALRY & ARMOR ASSOCIATION',
#  'NAME_13TH BOMB SQUADRON ASSOCIATION',
#  'NAME_146TH ALUMNI ASSOCIATION',
#  'NAME_14TH ARMORED DIVISION',
#  'NAME_150TH INTELLIGENCE SQUADRON ENLISTED ADVISORY COUNCIL',
#  'NAME_1632',
#  'NAME_180 CHURCH',
#  'NAME_180 YOUR GRIEF INC',
#  'NAME_1930S GENERAL STORE MUSEUM',
#  'NAME_1963 GIBBS ALUMNI INC',
#  'NAME_1999 VEBA OF THE NONREPRESENTED EMPLOYEES OF SOUTHERN CA EDISON',
#  'NAME_1K NATION INC',
#  'NAME_2 B NON PROFIT CORPORATION',
#  'NAME_2 X 2 INC',
#  'NAME_2000 PROJECT SOCCER',
#  'NAME_2041 FOUNDATION INCORPORATED',
#  'NAME_21ST CENTURY HARVEST FOUNDATION',
#  'NAME_21ST STREET FOUNDATION',
#  'NAME_2618 COMMERCIAL DRIVE INVESTMENT GROUP LLC',
#  'NAME_27TH DISTRICT AGRICULTURAL ASSOCIATION FRIENDS OF THE SHASTA',
#  'NAME_2833 EXCHANGE CLUB OF BARTLETT TN',
#  'NAME_29 PALMS FOOD FOR LIFE MINISTRY',
#  'NAME_2C2SMILE INC',
#  'NAME_2ND 2 NONE B TRAINING',
#  'NAME_2ND CORINTHIANS OUTREACH MINISTRIES INC',
#  'NAME_2ND IMAGE FOUNDATION INCORPORATED',
#  'NAME_2STINKYFISH INC',
#  'NAME_3 ANGELS MESSENGERS MOTORCYCLE ASSOCIATION',
#  'NAME_300 SWIM TEAM INC',
#  'NAME_360ARMOR INC',
#  'NAME_3615 VFW AUXILIARY TO PARNELL-BURT POST',
#  'NAME_361ST UNIT ADVISORY COUNCIL',
#  'NAME_37TH JUDICIAL COURT APPOINTED SPECIAL ADVOCATES CASA',
#  'NAME_3P FOUNDATION USA',
#  'NAME_3RD OSS BOOSTER CLUB',
#  'NAME_4 AG HAWAII INC',
#  'NAME_4 AMERICAN DREAM INC',
#  'NAME_4 CORNERS PROJECT INC',
#  'NAME_4 H CLUBS & AFFILITATED 4 H',
#  'NAME_4 HORSEMAN INVESTMENTS',
#  'NAME_4 LEGGED RESCUE',
#  'NAME_4 PAWS PANTRY',
#  'NAME_4 R FRIENDS- RESCUE REHAB RE-HOME REACH OUT',
#  'NAME_4 SQUARE INC - EDUCATIONAL',
#  'NAME_4 VFW AUX TO DISTRICT DEPARTMENT OF OREGON',
#  'NAME_4 WALLS INTERNATIONAL INCORPORATED',
#  'NAME_4-H CLUBS & AFFILIATED 4-H ORGANIZATIONS',
#  'NAME_4-H LEADERS FOUNDATION',
#  'NAME_40 WASHINGTON TENT',
#  'NAME_41 SOUTH VOLLEYBALL CLUB INC',
#  'NAME_41131 TOMBALL LIONS CLUB',
#  'NAME_42 SAMAJ OF GREATER KANSAS CITY INC',
#  'NAME_425',
#  'NAME_442 HRDC',
#  'NAME_45-11 FOUNDATION INCORPORATED',
#  'NAME_4963 AFT SALT LAKE COMMUNITY COLLEGE',
#  'NAME_4GARRETT - GWH FOUNDATION',
#  'NAME_4H HORSE SPECIALTY CLUB',
#  'NAME_4LEGS4JUSTICE ANIMAL ADVOCATE AND RESCUE',
#  'NAME_5 TALENTS MORE INC',
#  'NAME_5-MINUTE NUCLEAR CORPORATION',
#  'NAME_505 CHORUS',
#  'NAME_5116 MAGAZINE STREET PREPARATORY HIGH SCHOOL',
#  'NAME_5CS CHILD CARE CENTERS',
#  'NAME_5TG INC',
#  'NAME_647TH CIVIL ENGINEER SQUADRON BOOSTER CLUB',
#  'NAME_6800 BELLAIRE PROJECT INC',
#  'NAME_6TH SFS RATTLERS ASSOCIATION',
#  'NAME_83 UNITED INDEPENDENT SUPPORTERS ASSOCIATION',
#  'NAME_84 SLU MEDICINE SCHOLARSHIP PROGRAM',
#  'NAME_9-11 MEMORIAL FIRE TRUCK',
#  'NAME_911 PARK PLACE',
#  'NAME_97TH PENNSYLVANIA VOLUNTEER INSANTRY COMPANY A',
#  'NAME_9TH CAVALRY AND 25TH INFANTRY BUFFALO SOLDIERS OF LOUISIANA',
#  'NAME_A & S RESEARCH A CALIFORNIA BUSINESS TR',
#  'NAME_A AND M COMMUNITY DEVELOPMENT CORPORATION INC',
#  'NAME_A BED OF MY OWN INC',
#  'NAME_A BETTER BELIZE INC',
#  'NAME_A BETTER DAI',
#  'NAME_A BETTER SAN DIEGO ISSUES COMM A SPONSORED COMM OF SAN DIEGO AND',
#  'NAME_A BETTER TASTE FOR OUR COMMUNITY',
#  'NAME_A BIRTHDAY PARTY WISH INC',
#  'NAME_A BRIGHT FURUTURE FOR KIDS',
#  'NAME_A C I D A INC',
#  'NAME_A C T I O N MINISTRY',
#  'NAME_A CASE OF THE BLUES AND ALL THAT JAZZ',
#  'NAME_A CATHOLIC JOURNEY OF FAITH',
#  'NAME_A CENTER OF HOPE CPC INC',
#  'NAME_A CHANCE FOR THERAPY INC',
#  'NAME_A CHANCE INC',
#  'NAME_A CHANCE TO SHINE INC',
#  'NAME_A CHARITY CHALLENGE INC',
#  'NAME_A CHILDRENS THEATRE OF THE MESILLA VALLEY INC',
#  'NAME_A COMMUNITY PREGNANCY CENTER',
#  'NAME_A COURSE IN MIRACLES CENTER INC',
#  'NAME_A CUP OF COLD WATER',
#  'NAME_A DAY IN THE LIFE PROJECT INC',
#  'NAME_A DIAMOND IN THE RUFF INCORPORATED',
#  'NAME_A DOBERMAN ADOPTION PLACEMENT TEAM',
#  'NAME_A DOLLAR TODAY INC',
#  'NAME_A F T E R INC',
#  'NAME_A GIRLS PROMISE INCORPORATED',
#  'NAME_A HAND UP -- NOT A HAND-OUT',
#  'NAME_A HERO WAS HERE SGT JOHN KYLE DAGGETT FOUNDATION',
#  'NAME_A HOUSE OF THE LIVING GOD CHURCH OF JESUS CHRIST COJC INC',
#  'NAME_A HUMANITARIAN ORGANIZATION PROMOTING EDUCATION',
#  'NAME_A J MOUNTED RANGERS',
#  'NAME_A L S OF MIDDLE TENNESSEE',
#  'NAME_A LIFE WORTH LIVING',
#  'NAME_A LIFES WISH INC',
#  'NAME_A LOUD & CLEAR CALL MINISTRY',
#  'NAME_A M B A INC',
#  'NAME_A MILLION MATTERS INC',
#  'NAME_A MOTHERS MERCY THE SRC STORY',
#  'NAME_A MOTHERS TOUCH EDUCATION AND CARE CENTER',
#  'NAME_A MOUNTAIN COMMUNITY INCORPORATED',
#  'NAME_A NEW BEGINNING INC',
#  'NAME_A NEW DAY VOCATIONAL PROGRAM',
#  'NAME_A NEW FOCUS',
#  'NAME_A PROMISED LAND ANIMAL RESCUE INC',
#  'NAME_A SAFE PLACE COMMUNITY DEVELOPMENT CORPORATION',
#  'NAME_A SHEPHERDS LIFE 7 INC',
#  'NAME_A SOLUTION THROUGH TREATMENT',
#  'NAME_A TENDER LOVE AND CARE INC',
#  'NAME_A THEATRE NEAR U INC',
#  'NAME_A TIME FOR MERCY',
#  'NAME_A TU SALUD INC',
#  'NAME_A TUTORING PLACE',
#  'NAME_A VISION FOR WILMINGTON MINISTRIES',
#  'NAME_A VOICE IN THE WILDERNESS EMPOWERMENT CENTER',
#  'NAME_A WOMANS PLACE INC',
#  'NAME_A WOMENS PREGNANCY CENTER',
#  'NAME_A WOMENS PREGNANCY CENTER OF MADISON INC',
#  'NAME_A WORD FOR THE TIMES INC',
#  'NAME_A WORLD AWARE INC',
#  'NAME_A WORLD FOR CHILDREN',
#  'NAME_A WORLD INSTITUTE FOR A SUSTAINABLE HUMANITY - HELLAS - MESOGEIOU',
#  'NAME_A-FIB INC',
#  'NAME_AABY FOUNDATION',
#  'NAME_AACE INTERNATIONAL',
#  'NAME_AADF LEGACY AIRBASE INC',
#  'NAME_AAMA STATE OF OREGON SOCIETY LINN- BENTON CHAPTER',
#  'NAME_AAP CALIFORNIA CHAPTER 1 FOUNDATION',
#  'NAME_AARON BERINDA INTERNATIONAL MINISTRY INC',
#  'NAME_AARON KEITH ROBINSON FOUNDATION INC',
#  'NAME_AARON MAHLON ARTS & FRAMING',
#  'NAME_AAUW COLVILE BRANCH',
#  'NAME_AAUW TARRANT COUNTY BRANCH',
#  'NAME_AAVI INC',
#  'NAME_AAY HOME INCARCERATION TO COMMUNITY',
#  'NAME_ABANDONED BABIES CHRISTIAN MINISTRIES',
#  'NAME_ABANDONED CAT TEAM',
#  'NAME_ABATE MOTORCYCLE SAFETY EDUCATION PROGRAM',
#  'NAME_ABATE OF COLORADO',
#  'NAME_ABBA AGAPE CHURCH',
#  'NAME_ABBA FATHER MINISTRIES',
#  'NAME_ABBEY RHF HOUSING INC',
#  'NAME_ABBIES ANGELS',
#  'NAME_ABC INFANTS INC',
#  'NAME_ABC OF SOUTHERN CALIFORNIA BENEFIT TRUST FUND',
#  'NAME_ABC WORKFORCE DEVELOPMENT FOUNDATION',
#  'NAME_ABIDE154 INC',
#  'NAME_ABIDING IN HIS PRESENCE MINISTRIES',
#  'NAME_ABIDING IN THE VINE',
#  'NAME_ABIDING SOLUTIONS INTERNATIONAL MINISTRIES INCORPORATED',
#  'NAME_ABILENE CLEAN AND PROUD INC',
#  'NAME_ABILENE JUBILEE HOUSE INC',
#  'NAME_ABLE',
#  'NAME_ABLE COMMUNITY INC',
#  'NAME_ABODE COMMUNITY HOUSING',
#  'NAME_ABOGAR INTERNATIONAL MINISTRIES',
#  'NAME_ABOOUT FACE INC',
#  'NAME_ABOUT SOCCER INC',
#  'NAME_ABOUT-FACE MEDIA LITERACY INC',
#  'NAME_ABOVE ALL SPORTS',
#  'NAME_ABOVE AVERAGE LEARNING CENTERS',
#  'NAME_ABOVE THE SEAS LLC',
#  'NAME_ABRAHAM FOUNDATION INC',
#  'NAME_ABRAHAM LINCOLN ELEMENTARY BOOSTER CLUB',
#  'NAME_ABRAHAM LINCOLN HS BROOKLYN NY FLORIDA ALUMNI ASSOCIATION INC',
#  'NAME_ABRAZO FOSTER FAMILY AGENCY',
#  'NAME_ABUNDANCE ACADEMY',
#  'NAME_ABUNDANCE FOR LIFE',
#  'NAME_ABUNDANT LIFE FOR ALL MINISTRIES WORLDWIDE INC',
#  'NAME_ABUNDANT LIVING COMMUNITY ORGANIZATION INC',
#  'NAME_ABUSE RECOVERY MINISTRY & SERVICES',
#  'NAME_ABUSIVE DELIVERANCE IN PROGRESS INC',
#  'NAME_ACACIA FRATERNITY INCORPORATED',
#  'NAME_ACADEMIA DE LES LLETRES I BELLES ARTS',
#  'NAME_ACADEMIC AND COMMUNITY EXCELLENCE INCORPORATED',
#  'NAME_ACADEMIC EDGE FOR GIRLS IN SPORTS FOUNDATION',
#  'NAME_ACADEMIC INFROMER INC',
#  'NAME_ACADEMIC SCIENCE AND TECHNOLOGY CENTER INC',
#  'NAME_ACADEMICS PLUS CHARTER SCHOOL PARENT TEACHER ORGANIZATION INC',
#  'NAME_ACADEMIES OF OXFORD PREP',
#  'NAME_ACADEMY ADVISORY BOARD INC',
#  'NAME_ACADEMY FOR CERTIFICATION OF VISION REHABILITATION & EDUCATION PROFES',
#  'NAME_ACADEMY FUNDING OF BASTROP',
#  'NAME_ACADEMY GLOBAL LEARNING',
#  'NAME_ACADEMY MASTERS SWIM TEAM',
#  'NAME_ACADEMY OF CALIFORNIA ELITE SOCCER INC',
#  'NAME_ACADEMY OF CHINESE PERFORMING ARTS FOUNDATION',
#  'NAME_ACADEMY OF COMMUNITY THEATRE',
#  'NAME_ACADEMY OF GENERAL DENTISTRY',
#  'NAME_ACADEMY OF MANAGED CARE PHARMACY',
#  'NAME_ACADEMY OF TRANSDISCIPLINARY LEARNING AND ADVANCED STUDIES INC',
#  'NAME_ACADEMY PARENT CLUB',
#  'NAME_ACADIANA CHAPTER OF THE CONSTRUCTION SPECIFICATIONS',
#  'NAME_ACADIANA CUP FOUNDATION',
#  'NAME_ACADIANA DIAPER DEPOT INC',
#  'NAME_ACADIANA DOWN SYNDROME ASSOCIATION',
#  'NAME_ACADIANA GOOD TIMES ROLLERS',
#  'NAME_ACADIANA PRIDE FESTIVAL',
#  'NAME_ACC HOPE AZ',
#  'NAME_ACCCOLPH INC',
#  'NAME_ACCELERATION TRANSPORTATION RATE BUREAU INC',
#  'NAME_ACCELLERA ORGANIZATION',
#  'NAME_ACCEPTING CHALLENGES TO IMPROVE OUR NATION - COMMUNITY DEVLOPMENT CORP',
#  'NAME_ACCESS CENTER INC',
#  'NAME_ACCESS CONNECTIONS TO SUCCESS INC',
#  'NAME_ACCESS FOR CHANGE COMMUNITY DEVELOPMENT CORPORATION',
#  'NAME_ACCESS INSTITUTE',
#  'NAME_ACCESS TO EDUCATION EMPOWERMENT ECONOMIC DEVELOPMENT CORPORATION',
#  'NAME_ACCESSIBILITY INC',
#  'NAME_ACCOMPANIED BY GODS LOVE',
#  'NAME_ACCORD INC',
#  'NAME_ACCORD MINISTRIES INC',
#  'NAME_ACCOUNTABILITY PROJECT LLC',
#  'NAME_ACCOUNTING AND FINANCIAL WOMENS ALLIANCE',
#  'NAME_ACE EDUCATION INTERNATIONAL INC',
#  'NAME_ACE ENTERPRISES',
#  'NAME_ACE MENTOR PROGRAM OF AMERICA INC',
#  'NAME_ACEC TAX EXEMPT LIFE-HEALTH INS TR',
#  'NAME_ACF WESTERN USA INC',
#  'NAME_ACF-SMOKY MOUNTAIN CHAPTER',
#  'NAME_ACHIEVE COMMUNITY DEVELOPMENT CORPORATION',
#  'NAME_ACHIEVE FORT BEND COUNTY',
#  'NAME_ACHIEVEMENT REWARDS FOR COLLEGE SCIENTISTS FOUNDATION INC OREGON',
#  'NAME_ACHIEVEMENT REWARDS FOR COLLEGE SCIENTISTS FOUNDATION INC TAMPA BA',
#  'NAME_ACHIEVING LEADERSHIP INSTITUTE',
#  'NAME_ACHILLES DIVERS INC',
#  'NAME_ACI ALASKA CHAPTER',
#  'NAME_ACINN CORPORATION',
#  'NAME_ACIREMAS CREATIONS',
#  'NAME_ACLU FOUNDATION OF TEXAS INC',
#  'NAME_ACME FOUNDATION SRI THYAGARAJA MUSIC FESTIVAL',
#  'NAME_ACONA COMMUNITY OUTREACH',
#  'NAME_ACORN COMMUNITY LAND ASSOCIATION OF LA',
#  'NAME_ACRES OF DIAMONDS',
#  'NAME_ACSC INCORPORATED',
#  'NAME_ACT FOR A CAUSE INC',
#  'NAME_ACTION',
#  'NAME_ACTION COMMUNICATION AND EDUCATION REFORM',
#  'NAME_ACTION COUNCIL FOR 29 PALMS INC',
#  'NAME_ACTION UNITED FOR ENTERTAINERS AND DIVERSE ARTIST',
#  'NAME_ACTIONN',
#  'NAME_ACTIVE 20-30 CLUB OF SACRAMENTO NO 1',
#  'NAME_ACTIVE 20-30 UNITED STATES AND CANADA',
#  'NAME_ACTIVE FAMILY SERVICES',
#  'NAME_ACTIVE SINGLE CHRISTIAN SCIENTISTS ASSOCIATION',
#  'NAME_ACTIVE YOUTH AGAINST OBESITY',
#  'NAME_ACTIVELY VISITING ORPHANS WIDOWS ELDERLY AND DISABLED INC',
#  'NAME_ACTORS COMPANY AND THEATER SCHOOL',
#  'NAME_ACTS MINISTRY',
#  'NAME_ACTS MISSIONS',
#  'NAME_ACTS OF HOPE INC',
#  'NAME_ACTS4 COMMUNITY OUTREACH SERVICESINC',
#  'NAME_ACU ANGELS',
#  'NAME_ACUAVITA FOUNDATION INC',
#  'NAME_ACUSN-THE ARIZONA COLLEGE AND UNIVERSITY STUDENT NETWORK',
#  'NAME_ACWORTH ART CENTER',
#  'NAME_AD ASTRA AREA AQUATICS BOOSTER ASSOCIATION',
#  'NAME_AD FONTES',
#  'NAME_ADA COUNTY PARAMEDIC ASSOCIATION',
#  'NAME_ADA MBAISE USA INC',
#  'NAME_ADAIR EVANGELISTIC MINISTRIES INC',
#  'NAME_ADAM AND BRUCE HOUSING CORPORATION',
#  'NAME_ADAM MORGAN FOUNDATION',
#  'NAME_ADAM TULSA ENERGY NETWORK',
#  'NAME_ADAMO & CO LLC',
#  'NAME_ADAMS CAPE MEDICAL FUND INC',
#  'NAME_ADAMS COUNTY YOUTH INITIATIVE INC',
#  'NAME_ADAMS PROJECT INC',
#  'NAME_ADAMSVILLE ELEM PTA',
#  'NAME_ADAPTABLE SECURITY CORP',
#  'NAME_ADAPTIVE COMPUTER TRAINING INC',
#  'NAME_ADDICTION COUNSELING AND EDUCATION SERVICES INC',
#  'NAME_ADDICTION PROFESSIONALS ASSOCIATION FOR CALIFORNIA',
#  'NAME_ADDIE MAE LYNCH TR FBO THE BUTLER FAMILY CEMETERY',
#  'NAME_ADDISON ANONYMOUS GROUP CLUB',
#  'NAME_ADINKRA NOLA',
#  'NAME_ADIRONDACK 46R CONSERVATION TR',
#  'NAME_ADOG INC',
#  'NAME_ADOLESCENT TREATMENT CENTERS INC',
#  'NAME_ADOPT A GOLDEN BIRMINGHAM INC',
#  'NAME_ADOPT RESCUE DOGS',
#  'NAME_ADOPT SHELTER ANIMAL PETS - WEST RICHLAND',
#  'NAME_ADOPT-A-BIKE INCORPORATED',
#  'NAME_ADOSH MEMORIAL TR',
#  'NAME_ADP TOTALSOURCE INC HEALTH ANDWELFARE PLAN TRUST',
#  'NAME_ADRIENNE CASE MCDOWELL FOUNDATION',
#  'NAME_ADSI',
#  'NAME_ADULT & CHILDREN NUTRITION SERVICES INC',
#  'NAME_ADULT BASIC EDUCATION COUNCIL OF LAUDERDALE COUNTY TENNESSEE-ABE-',
#  'NAME_ADULT CONGENITAL HEARTS OF GREATER ATLANTA',
#  'NAME_ADULT FOSTER HOMECARE ASSOCIATION FOUNDATION OF HAWAII',
#  'NAME_ADULT FOSTER HOMECARE ASSOCIATIONOF HAWAII',
#  'NAME_ADULT LEARNING CENTER',
#  'NAME_ADULTS AND YOUTH UNITED DEVELOPMENT ASSOCIATION INC',
#  'NAME_ADULTS MANKIND ORGANIZATION INC',
#  'NAME_ADVANCE K9 SEARCH AND RECOVERY INC',
#  'NAME_ADVANCE PRODUCTIONS OF THOMAS CREEK RETREAT',
#  'NAME_ADVANCECAMP INC',
#  'NAME_ADVANCED MEDICAL HEALTH CENTER LLC',
#  'NAME_ADVANCED PLACEMENT EDUCATIONAL INSTITUTE',
#  'NAME_ADVANCED THERAPIES INCORPORATED',
#  'NAME_ADVANCEMENT THROUGH OPPORTUNITY AND KNOWLEDGE INCORPORATED',
#  'NAME_ADVANCING COMMUNITIES FOUNDATION',
#  'NAME_ADVANCING STEM FOR STUDENTS IN SOUTH TEXAS',
#  'NAME_ADVANTAGE FLAG FOOTBALL',
#  'NAME_ADVANTAGE NOLA TENNIS ASSOCIATION',
#  'NAME_ADVANTAGE SPORTS ACADEMY LLC',
#  'NAME_ADVENT OPENDOOR MINISTRIES A CALIFORNIA RELIGIOUS CORPORATION',
#  'NAME_ADVENTIST IHIE HIGH SCHOOL OLDSTUDENTS ASSOCIATION OF AMERICA INC',
#  'NAME_ADVENTIST INTERNATIONAL EYE SERVICES',
#  'NAME_ADVENTIST MEDICAL EVANGELISM NETWORK MEDIA INC',
#  'NAME_ADVENTIST VIRTUAL LEARNING NETWORK',
#  'NAME_ADVENTURE ACCESS GROUP INC',
#  'NAME_ADVENTURES IN ENGINEERING INC',
#  'NAME_ADVENTURES WITH JESUS MINISTRIES WITH JOHN MILLER',
#  'NAME_ADVISSORY COMMISSION ON TEXTBOOK SPECIFICATIONS INC',
#  'NAME_ADVOCACY RESOURCE CENTER INC',
#  'NAME_ADVOCAT TNR GROUP',
#  'NAME_ADVOCATES AGAINST DOMESTIC VIOLENCE IN THE AFRICAN AMERICAN COMMUNITY',
#  'NAME_ADVOCATES BELIEVING IN LIVING EMPOWERED',
#  'NAME_ADVOCATES FOR ACADEMIC EXCELLENCE IN EDUCATION INC',
#  'NAME_ADVOCATES FOR COMMUNITY CHOICE',
#  'NAME_ADVOCATES FOR HEALTHY COMMUNITIES INC',
#  'NAME_ADVOCATES FOR LATINO ARTS & CULTURE CONSORTIUM INC',
#  'NAME_ADVOCATES FOR SUSTAINABLE ANIMAL POPULATIONS',
#  'NAME_ADVOCATES FOR THE OAK RIDGE RESERVATION',
#  'NAME_ADVOCATES FOR VICTIMS OF ABUSE',
#  'NAME_ADVOCATES FOR VICTIMS OF IMPAIRED DRIVING',
#  'NAME_ADVOCATES OF PLANNED PARENTHOOD OF THE ST LOUIS REGION & SOUTHWEST MO',
#  'NAME_AEALAS INC',
#  'NAME_AEMP EDUCATION FOUNDATION',
#  'NAME_AEQUALIS INC',
#  'NAME_AERO INSTITUTE',
#  'NAME_AERONAUTICS EDUCATION ENTERPRISES',
#  'NAME_AEROSPACE CONTRACTORS TR',
#  'NAME_AEROSPACE LEGACY ENGINEERING AND TECHNOLOGY RECOVERY ORGANIZATION',
#  'NAME_AESOP INC',
#  'NAME_AESTHETIC SURGERY EDUCATION & RESEARCH FOUNDATION',
#  'NAME_AESTHETICIANS OF THE NORTHWEST',
#  'NAME_AF SELECT BASEBALL PEARLAND',
#  'NAME_AF WINGMOMS',
#  'NAME_AF WOMENS CYCLING CLUB',
#  'NAME_AFABWORLD',
#  'NAME_AFAST INC',
#  'NAME_AFC EMPLOYEE ALLIANCE',
#  'NAME_AFCEA EDUCATIONAL FOUNDATION',
#  'NAME_AFENMAI WORLD CONGRESS INC',
#  'NAME_AFFECT CHANGE',
#  'NAME_AFFILIATED INTERNATIONAL MINISTRIES',
#  'NAME_AFFIRMATION CENTER FOR THOUGHT INC',
#  'NAME_AFFIRMATIVE CONSENT PROJECT INC',
#  'NAME_AFFORDABLE HOUSING AND ECONOMIC DEVELOPMENT FOUNDATION',
#  'NAME_AFFORDABLE HOUSING PROVIDERS OF AMERICA',
#  'NAME_AFGE LOCAL 1711',
#  'NAME_AFGE NAVY SOUTHEAST COUNCIL AFL CIO C-243',
#  'NAME_AFGHANS4TOMORROW INC',
#  'NAME_AFM MINISTRY INC',
#  'NAME_AFRICA BOUND CORPORATION',
#  'NAME_AFRICA NEEDS COMMUNITY DEVELOPMENT DEPARTMENT',
#  'NAME_AFRICA RENEWAL MINISTRIES INC',
#  'NAME_AFRICAN AMERICAN BUSINESS LEADERSHIP COUNCIL INC',
#  'NAME_AFRICAN AMERICAN CLUB OF WEST PASCO COUNTY INC',
#  'NAME_AFRICAN AMERICAN DANCE REVIEW',
#  'NAME_AFRICAN AMERICAN EXPERIENCE MUSEUM INC',
#  'NAME_AFRICAN AMERICAN MUTUAL SUPPORT ASSOCIATES INC',
#  'NAME_AFRICAN AMERICAN REACH & TEACH HEALTH MINISTRY',
#  'NAME_AFRICAN AMERICAN WELLNESS PROJECT',
#  'NAME_AFRICAN AMERICAN WOMEN UNITED AAWU',
#  'NAME_AFRICAN AMERICAN YOUTH LEADERSHIP CONFERENCE',
#  'NAME_AFRICAN CARIBBEAN AMERICAN PERFORMING ARTISTS INC',
#  'NAME_AFRICAN GIRL EQUITY INC',
#  'NAME_AFRICAN GROVE INSTITUTE FOR THE ARTS CENTRAL TEXAS CHAPTER',
#  'NAME_AFRICAN MINISTRIES INTERNATIONAL',
#  'NAME_AFRICAN POLICY AND APPLIED RESEARCH INSTITUTE',
#  'NAME_AFRICAN SOCIAL AND IMMIGRATION SERVICES',
#  'NAME_AFRICAN STRATEGIC LEADERSHIP PRAYER NETWORK',
#  'NAME_AFRICAN UNION OF NORTHERN NEVADA CHARITIES',
#  'NAME_AFRICAN-AMERICAN MALE ACHIEVERS NETWORK',
#  'NAME_AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS',
#  'NAME_AFRIKAN CENTERED EDUCATION TASKFORCE INC',
#  'NAME_AFRIKAN CULTURAL RESEARCH AND STUDY GROUP OF LONG BEACH',
#  'NAME_AFSCME LOCAL 2076 ORANGE COUNTY BENEFITS TRUST',
#  'NAME_AFTER GODS HEART INC',
#  'NAME_AFTV FIVE',
#  'NAME_AGAINST ALL ODDS ALL BREED RESCUE',
#  'NAME_AGAINST ALL ODDS MINISTRIES',
#  'NAME_AGAINST HIV AIDS INC',
#  'NAME_AGAINST THE ODDS MENTORING SERVICES',
#  'NAME_AGAPE 4 ORPHANS INTERNATIONAL INC',
#  'NAME_AGAPE CHARITY HOUSE FOR KIDS',
#  'NAME_AGAPE CHILDRENS EMERGENCY SHELTER HOUSTON',
#  'NAME_AGAPE CHILDRENS MUSEUM',
#  'NAME_AGAPE CLINIC INC',
#  'NAME_AGAPE EDUCATIONAL MEDIA INC',
#  'NAME_AGAPE ENTERPRISES FOUNDATION INC',
#  'NAME_AGAPE FOOD PANTRY OF TAYLOR INC',
#  'NAME_AGAPE MINISTRIES GLOBAL',
#  'NAME_AGAPE WORLD CHRISTIAN MINISTRIES AND TRAINING CENTER',
#  'NAME_AGBEYOMI WORLD OUTREACH INC',
#  'NAME_AGE TO AGE INC',
#  'NAME_AGENCY FOR HOLISTIC EVANGELISM AND DEVELOPMENT INC',
#  'NAME_AGENTS ASSOCIATION',
#  'NAME_AGGIELAND PETS WITH A PURPOSE',
#  'NAME_AGING EAGLES CLUB INC',
#  'NAME_AGING IN PLACE - THE WOODLANDS',
#  'NAME_AGNES BRINKLUM TR UW 05181933',
#  'NAME_AGOFI OF USA',
#  'NAME_AGRICULTURE IMPLEMENTATION RESEARCH & EDUCATION',
#  'NAME_AHAVATH ACHIM CONGREGATION ENDOWMENT FUND INC',
#  'NAME_AHEAD INC',
#  'NAME_AHED INTERNATIONAL INC',
#  'NAME_AHH',
#  'NAME_AHISKA-TURKISH COMMUNITY CENTER OF ATLANTA INC',
#  'NAME_AHTANUM MISSION COUNCIL NO 6097 KNIGHTS OF COLUMBUS',
#  'NAME_AHUAS CLINIC FOUNDATION',
#  'NAME_AHUIMANU OHANA INCORPORATED',
#  'NAME_AID AFRICA',
#  'NAME_AID TO ABUSED WOMEN',
#  'NAME_AIDEN MARLEY HUGHES FOUNDATION INC',
#  'NAME_AIDING SHELTER ANIMALS PROJECT',
#  'NAME_AIDS TASKFORCE OF GREATER CLEVELAND INC',
#  'NAME_AIESEC ALUMNI IBEROAMERICA CORP',
#  'NAME_AIKI INTEGRATED ARTS',
#  'NAME_AIKIDO ACADEMY OF DENTON',
#  'NAME_AIKIDO DOJOS OF SAN ANTONIO',
#  'NAME_AIM AND FOCUS FOUNDATION',
#  'NAME_AIM HIGHER IN EDUCATION INCORPORATED',
#  'NAME_AIMUSIC SCHOOL',
#  'NAME_AIR & WASTE MANAGEMENT ASSOCIATION GULF COAST CHAPTER',
#  'NAME_AIR ALLIANCE HOUSTON',
#  'NAME_AIR AND WASTE MANAGEMENT ASSOCIATION GRAND CANYON SECTION',
#  'NAME_AIR FORCE ASSOCIATION',
#  'NAME_AIR FORCE ASSOICATION',
#  'NAME_AIR FORCE VILLAGES INC',
#  'NAME_AIR WARRIOR COURAGE FOUNDATION',
#  'NAME_AIREDALE TERRIER CLUB OF AMERICA CHARITABLE TR',
#  'NAME_AIRPORT ASSISTANCE CENTER INC',
#  'NAME_AIRPORT ROTARY FOUNDATION',
#  'NAME_AJS FOUNDATION INC',
#  'NAME_AKAKA SCHOLARS FOUNDATION',
#  'NAME_AKILAH CHAPTER 122',
#  'NAME_AKITA ADVOCATES RELOCATION TEAM ARIZONA',
#  'NAME_AKWA IBOM STATE ASSOCIATION - OREGON & WASHINGTON',
#  'NAME_AL-RAHMAN FOUNDATION WAQF',
#  'NAME_AL-SHIFA CLINIC INC',
#  'NAME_ALABAMA ALLIANCE FOR CHRISTIAN EDUCATION INC',
#  'NAME_ALABAMA ANIMAL CONTROL OFFICERS STANDARDS AND TRAINING COMMISSION',
#  'NAME_ALABAMA ASSOCIATION FOR PARENTS OF CHILDREN WITH VISUAL IMPAIRMENTS',
#  'NAME_ALABAMA ASSOCIATION FOR PLAY THERAPY',
#  'NAME_ALABAMA ASSOCIATION OF FEDERAL EDUCATION PROGRAM ADMINISTRATORS',
#  'NAME_ALABAMA ASSOCIATION OF WOMENS CLUBS INC',
#  'NAME_ALABAMA BEAUTY SALON CO-OP CENTER INC',
#  'NAME_ALABAMA BETA CHAPTER OF THE SIGMA PHI EPSILON FRATERNITY',
#  'NAME_ALABAMA BICYCLE COALITION',
#  'NAME_ALABAMA CHRISTIAN UNITED APPEAL FUND INC',
#  'NAME_ALABAMA COMMUNITY CARE - REGION A INC',
#  'NAME_ALABAMA COUNCIL FOR ADMIN & SPECIAL ED INC',
#  'NAME_ALABAMA EDGE',
#  'NAME_ALABAMA FAMILY CHILD CARE ASSOCIATION',
#  'NAME_ALABAMA FEDERATION OF WOMENS CLUBS',
#  'NAME_ALABAMA FOOD BANK ASSOCIATION INC',
#  'NAME_ALABAMA GREYHOUND RESCUE AND ADOPTION CENTER',
#  'NAME_ALABAMA HEALTHCARE CONSORTIUM LLC',
#  'NAME_ALABAMA INDIA TRADE DEVELOPMENT',
#  'NAME_ALABAMA KINDERGARDEN CONFERENCE INC',
#  'NAME_ALABAMA LATIN AMERICAN ASSOCIATION',
#  'NAME_ALABAMA LEAGUE FOR NURSING',
#  'NAME_ALABAMA NONPROFIT EATING DISORDERSASSISTANCE FOUNDATION',
#  'NAME_ALABAMA OPTOMETRIC ASSOCIATION',
#  'NAME_ALABAMA POWER SERVICE ORGANIZATION INC',
#  'NAME_ALABAMA REGION S C C A',
#  'NAME_ALABAMA RIVER REGION BALLET SCHOOL AND YOUTH COMPANY',
#  'NAME_ALABAMA SOCIETY FOR THE PREVENTION OF CRUELTY TO ANIMALS',
#  'NAME_ALABAMA SYMPHONY ORCHESTRA MUSICIANS INC',
#  'NAME_ALABAMA TREASURE FOREST ASSOCIATION',
#  'NAME_ALABAMA TRIBE BASEBALL',
#  'NAME_ALABAMA URBAN AND REGIONAL INFORMATION SYSTEMS ASSOCIATION',
#  'NAME_ALABAMA USA YOUTH ENHANCEMENT ALUMNI',
#  'NAME_ALABAMA VETERINARY SERVICES',
#  'NAME_ALABAMA WATER POLLUTION CONTROL ASSOCIATION',
#  'NAME_ALABAMA WILDERNESS MEDICAL ASSOCIATION INC',
#  'NAME_ALABAMA YOUTH BALLET COMPANY',
#  'NAME_ALABAMENSE CHAPTER OF THE AZELEA SO CIETY OF AMERICA INCORPORATED',
#  'NAME_ALABASTER ENTERPRISES CORP',
#  'NAME_ALABASTER MINISTRIES INTERNATIONAL INC',
#  'NAME_ALAJAWAN BROWN FOUNDATION',
#  'NAME_ALAMEDA BUSINESS NETWORK INC',
#  'NAME_ALAMEDA COUNTY FAMILY JUSTICE CENTER INC',
#  'NAME_ALAMEDA WEST FOUNDATION',
#  'NAME_ALAMO AREA AIKIKAI',
#  'NAME_ALAMO AREA ASSOCIATION OF SCHOOL',
#  'NAME_ALAMO CITY OPERA',
#  'NAME_ALAMO CITY STORM SOCCER CLUB',
#  'NAME_ALAMO ENDOWMENT',
#  'NAME_ALAMO HEAD INJURY ASSOCIATION INC',
#  'NAME_ALAMO SILVER WINGS AIRBORNE ASSOCIATION',
#  'NAME_ALAMOGORDO FORUM',
#  'NAME_ALAMOGORDO TWICE BLEST COMMUNITY PUBLIC CHARITY',
#  'NAME_ALAN LI MEMORIAL TR',
#  'NAME_ALANO CLUB COUNTY EAST INC',
#  'NAME_ALASKA APPENTRICESHIP AND TRAINING COORDINATORS ASSOCIATION INC',
#  'NAME_ALASKA ARTS EDUCATION CONSORTIUM INC',
#  'NAME_ALASKA ASSOCIATION OF HARBORMASTERS AND PORT ADMINISTRATORS INC',
#  'NAME_ALASKA ASSOCIATION OF STUDENT FINANCIAL AID ADMINISTRATORS',
#  'NAME_ALASKA BEARFEST INC',
#  'NAME_ALASKA BRAIN INJURY NETWORK INC',
#  'NAME_ALASKA BULLY RESCUE LLC',
#  'NAME_ALASKA CHRISTIAN WOMENS MINISTRY',
#  'NAME_ALASKA COMMUNITY ACTION ON TOXICS',
#  'NAME_ALASKA DAY FESTIVAL INC',
#  'NAME_ALASKA DIVE SEARCH RESCUE AND RECOVERY TEAM',
#  'NAME_ALASKA MOVING IMAGES PRESERVATION ASSOCIATION',
#  'NAME_ALASKA MUSIC EDUCATORS ASSOCIATION INC',
#  'NAME_ALASKA NATIVE COALITION ON EMPLOYMENT AND TRAINING INC',
#  'NAME_ALASKA PTA',
#  'NAME_ALASKA RURAL VETERINARY OUTREACH INC',
#  'NAME_ALASKA SCHOOL COUNSELOR ASSOC INC',
#  'NAME_ALASKA SCIENCE PUB',
#  'NAME_ALASKAN ANIMAL RESCUE FRIENDS',
#  'NAME_ALASKAN MARINE MINISTRIES',
#  'NAME_ALASKANS FOR LANGUAGE ACQUISITION INC',
#  'NAME_ALBA CARE SERVICES INC',
#  'NAME_ALBANIAN-AMERICAN CULTURAL CENTER INC',
#  'NAME_ALBANY ALUMNI CHAPTER OF KAPPA ALPHA PSI INC',
#  'NAME_ALBANY POLICE ACTIVITIES LEAGUE',
#  'NAME_ALBANY POST NO 292 THE AMERICAN LEGION DEPARTMENT OF CA',
#  'NAME_ALBANY STATE UNIVERSITY NATIONAL ALUMNI ASSOCAITION',
#  'NAME_ALBANY STATE UNIVERSITY NATIONAL ALUMNI ASSOCIATION',
#  'NAME_ALBERT EINSTEIN FELLOWSHIP ALUMNI ASSOCIATION',
#  'NAME_ALBERT EINSTEIN MEDICAL CENTER PHILADELPHIA COLLEGE OF',
#  'NAME_ALBERT FARINE ELEMENTARY PARENT TEACHER ORGANIZATION- PTO',
#  'NAME_ALBERTVILLE PEOPLE PROVIDING LOVE AND EDUCATION INC',
#  'NAME_ALBUQUERQUE BARBERSHOP COMMUNITY CONSORTIUM',
#  'NAME_ALBUQUERQUE FIBER ARTS COUNCIL INC',
#  'NAME_ALBUQUERQUE GAME DEVELOPERS GUILD',
#  'NAME_ALBUQUERQUE GED',
#  'NAME_ALBUQUERQUE REGIONAL COALITION FOR HEALTHCARE PREPAREDNESS ARCH-P',
#  'NAME_ALBUQUERQUE REMOTE CONTROLLED OFF- ROAD RACEWAY',
#  'NAME_ALC INC',
#  'NAME_ALCOHOL TOBACCO AND OTHER DRUGS COALITION OF LAWRENCE COUNTY',
#  'NAME_ALCOR ENDOWMENT TR SUPPORTING ORGANIZATION 10142013',
#  'NAME_ALDEN MASON CHARITABLE FOUNDATION FOR THE ARTS',
#  'NAME_ALDERSGATE HEALTHCARE INC',
#  'NAME_ALDERSGATE MEDICAL SERVICES',
#  'NAME_ALDERSGATE RETIREMENT INC',
#  'NAME_ALEGRIA MONTESSORI SCHOOL INC',
#  'NAME_ALEMAP FOUNDATION',
#  'NAME_ALERO INC',
#  'NAME_ALETHEIA PROJECT',
#  'NAME_ALEVRO INC ROMANIAN EVANGELICAL ALLIANCE OF FLORIDA',
#  'NAME_ALEX MCDONALD FOUNDATION INC',
#  'NAME_ALEXANDER ART SPACE INCORPORATED',
#  'NAME_ALEXANDER CURRY KENDALL MEMORIAL FUND',
#  'NAME_ALEXANDER HAMILTON HIGH SCHOOL ALUMNI ASSOCIATION',
#  'NAME_ALEXANDER MINISTRIES INTERNATIONAL INC',
#  'NAME_ALEXANDRIA AFFORDABLE HOUSING CORPORATION',
#  'NAME_ALEXANDRIAS GRACE AND ETIQUETTE',
#  'NAME_ALEXIS ANGEL MINISTRIES',
#  'NAME_ALEXIS SAND KASTLES INC',
#  'NAME_ALFRED ADKINSON MINISTRIES INC',
#  'NAME_ALFRED FLEISHMAN SUMMER CAMPS',
#  'NAME_ALHAMBRA HIGH SCHOOL ARTS FOUNDATION',
#  'NAME_ALI I BEACH OHANA INC',
#  'NAME_ALIAS CHAMBER ENSEMBLE',
#  'NAME_ALICE G HARRISON MEMORIAL TRUST',
#  'NAME_ALICE G OGG TRUST',
#  'NAME_ALICE P TEATER TR UA 041282',
#  'NAME_ALICE R BARBARIS CHARITABLE TRUST',
#  'NAME_ALICE SWIM TEAM PARENTS CLUB',
#  'NAME_ALICES FOSTER TRANSITION ENTERPRISES RESOURCES',
#  'NAME_ALICIA GONZALEZ CEREN FOUNDATION',
#  'NAME_ALICIA SOS INC',
#  'NAME_ALIENATED GRANDPARENTS ANONYMOUS INCORPORATED',
#  'NAME_ALII COMMUNITY CARE INCORPORATED',
#  'NAME_ALIJON CHARITABLE TR',
#  'NAME_ALIPATO PROJECT',
#  'NAME_ALIVE AGAIN LIFE RECOVERY MISSION',
#  'NAME_ALKI PTSA',
#  'NAME_ALL 4 U RECREATIONAL COMMUNITY CENTER INC',
#  'NAME_ALL ABOUT EQUINE ANIMAL RESCUE',
#  'NAME_ALL AMERICAN FAMILIES',
#  'NAME_ALL BEAUTIFUL CHILDREN ENRICHMENT LEARNING CENTER',
#  'NAME_ALL BREED HORSE SHOW ASSOCIATION',
#  'NAME_ALL CHRISTIANS TOGETHER SERVING',
#  'NAME_ALL CREATURES GREAT AND SMALL WILDLIFE INC',
#  'NAME_ALL DOGS OFFICIAL RESCUE ENTERPRISE',
#  'NAME_ALL FEET UP NON-PROFIT ORGANIZATION',
#  'NAME_ALL FOR THE INCREDIBLE KIDS INC',
#  'NAME_ALL IN MULTISPORT LLC',
#  'NAME_ALL IN OUTREACH',
#  'NAME_ALL KIDZ INC',
#  'NAME_ALL ONE FAMILY INC',
#  'NAME_ALL OR NOTHIN',
#  'NAME_ALL OUT CARING INC',
#  'NAME_ALL PAWS MATTER INC',
#  'NAME_ALL PEOPLES ENCINITAS INC',
#  'NAME_ALL POINTS WEST GERMAN SHORTHAIRED POINTER RESCUE',
#  'NAME_ALL POSITIVES POSSIBLE',
#  'NAME_ALL PRO SPORTS TRAINING ACADEMY INCORPORATED',
#  'NAME_ALL RETRIEVER RESCUE FOUNDATION',
#  'NAME_ALL SOULS CROSSROAD CHURCH INC',
#  'NAME_ALL THAT IS CORP',
#  'NAME_ALL TRI INC',
#  'NAME_ALL WALKS OF LIFE INC',
#  'NAME_ALL-STAR DANCE FOUNDATION INC',
#  'NAME_ALL-STAR ORCHESTRA SUMMIT',
#  'NAME_ALL4KIDS FOUNDATION',
#  'NAME_ALLEGRO PERFORMERS PARENTS ASSOCIATION',
#  'NAME_ALLEN AND ALICE STOKES NATURE CENTE R',
#  'NAME_ALLEN MINISTRY SERVICES INC',
#  'NAME_ALLEN WARD MINISTRIES',
#  'NAME_ALLEN-MCRIGHT CEMETERY FUND',
#  'NAME_ALLENSWORTH PROGRESSIVE ASSOCIATION',
#  'NAME_ALLEYNE BERCY GROUP',
#  'NAME_ALLIANCE 2005',
#  'NAME_ALLIANCE FOR ACCREDITATION & CERTIFICATION OF STRUCTURED',
#  'NAME_ALLIANCE FOR ARIZONA ANIMAL PROTECTION',
#  'NAME_ALLIANCE FOR COMMUNITY SOLUTIONS LTD',
#  'NAME_ALLIANCE FOR COMPANION ANIMALS INC',
#  'NAME_ALLIANCE FOR COMPASSION AND TOLERANCE',
#  'NAME_ALLIANCE FOR DEVELOPING EDUCATION',
#  'NAME_ALLIANCE FOR INTERNATIONAL REFORESTATION INC',
#  'NAME_ALLIANCE FOR PERSERVING THE TRUTH OF SINO-JAPAN WAR',
#  'NAME_ALLIANCE FOR RETAIL MARKETS',
#  'NAME_ALLIANCE FOR RETIRED AMERICANS',
#  'NAME_ALLIANCE FOR STERILIZING ANY PET',
#  'NAME_ALLIANCE FOR TECHNOLOGY EDUCATION IN ADVANCED MATH AND SCIENCE CORP',
#  'NAME_ALLIANCE FOR YOUNG FUTURE FILMMAKERS',
#  'NAME_ALLIANCE FRANCAISE DE TALLAHASSEEINC',
#  'NAME_ALLIANCE HOUSE COMMUNITY OF KNOXVILLE',
#  'NAME_ALLIANCE LENDING CORPORATION',
#  'NAME_ALLIANCE OF BLACK LUCENT EMPLOYEES INC',
#  'NAME_ALLIANCE OF BORDER COLLABRATIVES',
#  'NAME_ALLIANCE OF DIVINE LOVE INC',
#  'NAME_ALLIANCE OF GREATER ROBERTS AREA',
#  'NAME_ALLIANCE OF INDEPENDENT BIGFOOT RESEARCHERS',
#  'NAME_ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY LIBRARY',
#  'NAME_ALLIANCE OF THE FRIENDS OF THE DEKALB COUNTY PUBLIC LIBRARY',
#  'NAME_ALLIANCE OUTREACH MINISTRIES OF IOWA PARK TEXAS',
#  'NAME_ALLIANCE PERFORMANCE CENTER OF TUCSON',
#  'NAME_ALLIANCE SUPPORT CORP',
#  'NAME_ALLIANCE TO REUNITE & REPAIR OUR WORLD',
#  'NAME_ALLIANCE TO STOP SLAVERY AND END TRAFFICKING',
#  'NAME_ALLIANT HEALTH SOLUTIONS INC',
#  'NAME_ALLIED ARTS FOUNDATION AFFILIATED FUND OF THE OKLAHOMA CITY',
#  'NAME_ALLIED COMMUNITIES OF TULSA INSPIRING OUR NEIGHBORHOODS INC',
#  'NAME_ALLIED MASONIC DEGREES',
#  'NAME_ALLIED WOMEN ENTREPRENEURS',
#  'NAME_ALLIES FOR SUBSTANCE ABUSE PREVENTION OF ANDERSON COUNTY INC',
#  'NAME_ALLIES LINKED FOR THE PREVENTION OF HIV AND AIDS',
#  'NAME_ALLISON GRAY BRODERICK FOUNDATION',
#  'NAME_ALLOTTEES ASSOCIATION & AFFILIATED TRIBES OF THE QUINAULT RESERVATION',
#  'NAME_ALLUME SOCIETY',
#  'NAME_ALLYS HAVEN',
#  'NAME_ALMA INC ALIANZA DE LIDEREZ MEXICANOS Y AMERICANOS',
#  'NAME_ALMA MATER INC',
#  'NAME_ALMS INTERNATIONAL MINISTRIES',
#  'NAME_ALOHA CHAPTER OF THE AMERICAN SOCIETY OF MILITARY COMPTROLLERS',
#  'NAME_ALOHA ILIO RESCUE',
#  'NAME_ALOHA SPIRIT',
#  'NAME_ALOHA SPIRIT FOUNDATION',
#  'NAME_ALPACA BREEDERS ALLIANCE OF NORTHERN COLORADO',
#  'NAME_ALPACA RANCHERS OF THE NORTHWEST',
#  'NAME_ALPH PHI SIGMA',
#  'NAME_ALPHA ACADEMY',
#  'NAME_ALPHA AGAPE INC',
#  'NAME_ALPHA COMMUNITIES INTERNATIONAL',
#  'NAME_ALPHA DELTA KAPPA SORORITY INC',
#  'NAME_ALPHA EDUCATION AND ECONOMIC DEVELOPMENT FOUNDATION OF ACADIANA',
#  'NAME_ALPHA ETA NATIONAL HONOR SOCIETY',
#  'NAME_ALPHA ETA ZETA DOVE FOUNDATION INC',
#  'NAME_ALPHA GAMMA RHO FRATERNITY',
#  'NAME_ALPHA IOTA EDUCATIONAL FOUNDATION',
#  'NAME_ALPHA KAPPA ALPHA SORORITY INC',
#  'NAME_ALPHA KAPPA PSI FRATERNITY',
#  'NAME_ALPHA MASTER CHAPTER OF BETA SIGMA PHI',
#  'NAME_ALPHA OMEGA INTERNATIONAL DENTAL FRATERNITY INC',
#  'NAME_ALPHA OMICRON PI FRATERNITY INC',
#  'NAME_ALPHA PHI IGMA',
#  'NAME_ALPHA PHI INTERNATIONAL FRATERNITY INC',
#  'NAME_ALPHA PHI OMEGA',
#  'NAME_ALPHA PHI SIGMA',
#  'NAME_ALPHA PHI SIGMA ALPHA LAMBDA SIGMA - KINGS COLLEGE',
#  'NAME_ALPHA PHI SIGMA INC',
#  'NAME_ALPHA PSYCHOLOGICAL CHRISTIAN CONCEPTS INC',
#  'NAME_ALPHA SIGMA ALPHA SORORITY',
#  'NAME_ALPHA SIGMA PHI FRATERNITY INC',
#  'NAME_ALPHA SUBDIVISION COMMITTEE INC',
#  'NAME_ALPHA TAU OMEGA FRATERNITY',
#  'NAME_ALPHA XI DELTA FRATERNITY',
#  'NAME_ALPHA ZETA EPSILON CHARTER CSUF',
#  'NAME_ALPHA-1 FOUNDATION INC',
#  'NAME_ALPHARETTA ELEMENTARY SCHOOL FOUNDATION INC',
#  'NAME_ALPINE OUTDOOR RECREATION ASSOCIATION',
#  'NAME_ALPINES INTERNATIONAL CLUB',
#  'NAME_ALS ASSOCIATION MID AMERICA CHPTR',
#  'NAME_ALS EMERGENCY TREATMENT FUND',
#  'NAME_ALSION MONTESSORI FOUNDATION',
#  'NAME_ALT AFFORDABLE HOUSING SERVICES INC - ARBOR PLACE',
#  'NAME_ALTA ARTS COUNCIL',
#  'NAME_ALTA VISTA CENTER FOR AUTISM',
#  'NAME_ALTA VISTA PUBLIC CHARTER INC',
#  'NAME_ALTERNATIVE CANCER RESEARCH FUND',
#  'NAME_ALTERNATIVE COMMUNITY SOLUTIONS ECONOMIC DEVELOPMENT CORPORATION',
#  'NAME_ALTERNATIVE HEALTHCARE ACCESS CAMPAIGN',
#  'NAME_ALTERNATIVE MINISTRIES INC',
#  'NAME_ALTERNATIVE SCHOOLS INC',
#  'NAME_ALTERNATIVE SEMINARY',
#  'NAME_ALTERNATIVE SEXUALITIES HEALTH RESEARCH ALLIANCE',
#  'NAME_ALTERNATIVE TO MARRIAGE PROJECT INC',
#  'NAME_ALTERNATIVES TO GUARDIANSHIP',
#  'NAME_ALTERNATIVES TO VIOLENCE PROJECT USA INC',
#  'NAME_ALTRUISM ACROSS BORDERS INC',
#  'NAME_ALTRUSA CLUB OF CLOVIS NEW MEXICO FOUNDATION',
#  'NAME_ALTRUSA INTERNATIONAL FOUNDATION INC',
#  'NAME_ALTUS MATH',
#  'NAME_ALTUS-LAUREL INC',
#  'NAME_ALUMNAE ASSOCIATION OF MOUNT HOLYOKE COLLEGE INC',
#  'NAME_ALUMNI AND VOLUNTEER CORPORATION OF THE CALIFORNIA BETA',
#  'NAME_ALUMNI ASSOCIATION OF NORTHERN LUZON ADVENTIST COLLEGE',
#  'NAME_ALUMNI ASSOCIATION OF PASAY CITY ACADEMY',
#  'NAME_ALUMNI ASSOCIATION OF THE UNIVERSITY OF TEXAS OF THE PERMIAN',
#  'NAME_ALUMNI FOUNDATION OF VACAVILLE HIGH SCHOOL CLASS OF 1992',
#  'NAME_ALUMNI INTERFRATERNITY COUNCIL AT THE UNIVERSITY OF WASHINGTON',
#  'NAME_ALUUTAALAAHU COMMUNITY DEVELOPMENT CORPORATION',
#  'NAME_ALWANI GROUP FOUNDATION INC',
#  'NAME_ALYBOO & IZYBEE FOUNDATION INC',
#  'NAME_ALYDEN FOUNDATION',
#  'NAME_ALZAR SCHOOL INC',
#  'NAME_AM-RU INTERNATIONAL ASSOCIATION',
#  'NAME_AMACHI VISION CORPS INC',
#  'NAME_AMADOR VALLEY HIGH SCHOOL SENIOR CLASS PARENTS',
#  'NAME_AMAIMO COMMUNITY USA INCORPORATED',
#  'NAME_AMAL ACADEMY INC',
#  'NAME_AMALGAMATED TRANSIT UNION',
#  'NAME_AMAN PROFESSIONAL NURSING INSTITUTE INC',
#  'NAME_AMARAS SMILE BILIARY ATRESIA AWARENESS',
#  'NAME_AMARILLO AREA PARKINSON ASSOCIATION',
#  'NAME_AMARILLO BLUE SOFTBALL',
#  'NAME_AMARILLO COMPETITIVE FENCING ASSOCIATION',
#  'NAME_AMARILLO HOCKEY ASSOCIATION INC',
#  'NAME_AMARILLO YCCO',
#  'NAME_AMATEUR ATHELTIC UNION OF THE UNITED STATES INC',
#  'NAME_AMATEUR ATHLETIC UNION OF THE U S INC',
#  'NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATE INC',
#  'NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES',
#  'NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC',
#  'NAME_AMATEUR ATHLETIC UNION OV THE UNITED STATES INC',
#  'NAME_AMATEUR ATHLETIC UNIONS OF THE UNITED STATES INC',
#  'NAME_AMATEUR ATHLETIC UNIONS OF THE US',
#  'NAME_AMATEUR ATHLETICS COMMISSION OF SNOHOMISH COUNTY',
#  'NAME_AMATEUR COMMUNITY THEATRE OF ROWLETT',
#  'NAME_AMATOR INSTITUTE INC',
#  'NAME_AMAZING GRAYS MINISTRY',
#  'NAME_AMAZINGLY UNIQUE BABIES REDEFINING THE IMPOSSIBLE INC',
#  'NAME_AMAZON INLAND MISSION INC',
#  'NAME_AMBASSADOR FINANCIAL INC',
#  'NAME_AMBASSADOR NETWORK',
#  'NAME_AMBASSADOR TRUST',
#  'NAME_AMBASSADOR WORLDWIDE HOLISTIC MINISTRIES ASSOCIATION',
#  'NAME_AMBASSADORS FOR CHRIST FELLOWSHIP',
#  'NAME_AMBASSADORS FOR CHRIST INC',
#  'NAME_AMBASSADORS FOR CHRIST WORSHIP CENTER INC',
#  'NAME_AMBER ROSE POWER INC',
#  'NAME_AMBULANCE GATEWAY INC',
#  'NAME_AMBULATORY SURGERY ACCESS COALITION',
#  'NAME_AMCA ASSOCIATION FOR MODERN AND CONTEMPORARY ART',
#  'NAME_AMELIA ISLAND EQUITY CLUB INC',
#  'NAME_AMEN FILMS INC',
#  'NAME_AMEN OUTREACH MINISTRY',
#  'NAME_AMER FED OF STATE COUNTY & MUNICIPAL EMPLOYEES AFSCME CA PEOP',
#  'NAME_AMERASIANS WITHOUT BORDERS',
#  'NAME_AMERCIAN LEGION',
#  'NAME_AMERIANS UNITED FOR SEPARATION OF CHURCH AND STATE',
#  'NAME_AMERICA BIBLE INSTITUTE',
#  'NAME_AMERICA CUP INC',
#  'NAME_AMERICA FEDERATION OF LABOR AND CONGRESS OF INDUSTRIAL ORGS',
#  'NAME_AMERICA LETS ROLL INC',
#  'NAME_AMERICA REACHING CHILDREN PROJECT',
#  'NAME_AMERICA SCORES DALLAS',
#  'NAME_AMERICA SEARCH AND RESCUE',
#  'NAME_AMERICAN ACADEMY OF CRANIOMAXILLOFACIAL SURGEONS',
#  'NAME_AMERICAN ACADEMY OF FAMILY PHYSICIANS',
#  'NAME_AMERICAN ACADEMY OF OPTOMETRY',
#  'NAME_AMERICAN ACADEMY OF PEDIATRICS CALIFORNIA DISTRICT',
#  'NAME_AMERICAN ACADEMY OF PROCEDURAL CODERS',
#  'NAME_AMERICAN ACADEMY OF VETERINARY ACUPUNCTURE INC',
#  'NAME_AMERICAN AGAPE FOUNDATION INC',
#  'NAME_AMERICAN ALBANIAN ENCOURAGEMENT FOUNDATION TR',
#  'NAME_AMERICAN ALZHEIMERS RESEARCH ORGANIZATION',
#  'NAME_AMERICAN ART THERAPY ASSOCIATION',
#  'NAME_AMERICAN ART THERAPY ASSOCIATION INC',
#  'NAME_AMERICAN ASSOC OF UNIVERSITY WOMEN',
#  'NAME_AMERICAN ASSOCIATION FOR PRIMARY CARE ENDOSCOPY',
#  'NAME_AMERICAN ASSOCIATION FOR TAXI CABS FOUNDATION INC',
#  'NAME_AMERICAN ASSOCIATION FOR TAXI CABS INC',
#  'NAME_AMERICAN ASSOCIATION FOR THE CHILDS RIGHT TO PLAY',
#  'NAME_AMERICAN ASSOCIATION FOR WIND ENGINEERING',
#  'NAME_AMERICAN ASSOCIATION OF ADAPTED SPORTS PROGRAMS INC',
#  'NAME_AMERICAN ASSOCIATION OF BIRTH CENTERS',
#  'NAME_AMERICAN ASSOCIATION OF BLACKS IN ENERGY',
#  'NAME_AMERICAN ASSOCIATION OF BLACKS IN ENERGY-TENNESSEE CHAPTER',
#  'NAME_AMERICAN ASSOCIATION OF CANDY TECHNOLOGIST',
#  'NAME_AMERICAN ASSOCIATION OF DRILLING ENGINEERS',
#  'NAME_AMERICAN ASSOCIATION OF FAMILY AND CONSUMER SCIENCES',
#  'NAME_AMERICAN ASSOCIATION OF HEALTHCARE ADMINISTRATION MANAGEMENT',
#  'NAME_AMERICAN ASSOCIATION OF KIDNEY PATIENTS INC',
#  'NAME_AMERICAN ASSOCIATION OF MULTI-SENSORY ENVIRONMENTS',
#  'NAME_AMERICAN ASSOCIATION OF NEUROPAT',
#  'NAME_AMERICAN ASSOCIATION OF PSYCHIATRIC TECHNICIANS',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERISTY WOMEN',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY OF WOMEN INC',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN ALBANY BRANCH',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN AUBURN CA BRANCH',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN INC',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN LOCAL SCHOLARSHIP FUND',
#  'NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN TAHOE NEVADA BRANCH',
#  'NAME_AMERICAN ASSOCIATION OF UNVERSITY WOMEN',
#  'NAME_AMERICAN ASSOCIATION OF ZOO KEEPERS',
#  'NAME_AMERICAN ASSOCIATION ON INTELLECTUAL & DEVELOPMENTAL DISAB',
#  'NAME_AMERICAN AUXILLARY CALISPEL',
#  'NAME_AMERICAN BACKFLOW PREVENTION ASSOCIATION',
#  'NAME_AMERICAN BALINT SOCIETY',
#  'NAME_AMERICAN BAPTIST ESTATES INC',
#  'NAME_AMERICAN BAPTIST HOMES OF WASHINGTON',
#  'NAME_AMERICAN BEGONIA SOCIETY',
#  'NAME_AMERICAN BONE HEALTH',
#  'NAME_AMERICAN BRITTANY CLUB INC',
#  'NAME_AMERICAN BUREAU OF SHIPPING VEBA MASTER TRUST',
#  'NAME_AMERICAN BUSINESS WOMENS ASSN AIRPORT CHARTER CHAPTER',
#  'NAME_AMERICAN BUSINESS WOMENS ASSOCIATION',
#  'NAME_AMERICAN CANCER SOCIETY INC',
#  'NAME_AMERICAN CANYON ATLETICO FUTBOL CLUB',
#  'NAME_AMERICAN CASE MANAGEMENT ASSOCIATION UTAH CHAPTER',
#  'NAME_AMERICAN CAT SOCIETY INC',
#  'NAME_AMERICAN CATHOLIC CHURCH ARTWALK',
#  'NAME_AMERICAN CHARITABLE ENTERPRISES INCORPORATED',
#  'NAME_AMERICAN CHARITIES INC',
#  'NAME_AMERICAN CHEMICAL SOCIETY',
#  'NAME_AMERICAN CHESAPEAKE CLUB CHARITABLE TR',
#  'NAME_AMERICAN CHRISTIAN FICTION WRITERS',
#  'NAME_AMERICAN CHRISTIAN FICTION WRITERS INC',
#  'NAME_AMERICAN CHRISTIAN MILITARY ACADEMY OF EXCELLENCE',
#  'NAME_AMERICAN CHUCK WAGON ASSOCIATION',
#  'NAME_AMERICAN COACH ASSOCIATION',
#  'NAME_AMERICAN COACH ASSOCIATION SCHOLARSHIP FOUNDATION INC',
#  'NAME_AMERICAN COALITION INC',
#  'NAME_AMERICAN COLLEGE OF EMERGENCY PHYSICIANS',
#  'NAME_AMERICAN COLLEGE OF HEALTHCARE EXECUTIVES',
#  'NAME_AMERICAN COLLEGE OF NURSE MIDWIVES',
#  'NAME_AMERICAN COLLEGE OF NURSE-MIDWIVES',
#  'NAME_AMERICAN COLLEGE OF PHYSICIANS',
#  'NAME_AMERICAN COLLEGE OF PHYSICIANS SERVICES',
#  'NAME_AMERICAN COLLEGE OF VETERINARY DERMATOLOGY RESEARCH FOUNDATION',
#  'NAME_AMERICAN CONTRACTORS TRUST FOR THE STATE OF',
#  'NAME_AMERICAN CONTRACTORS TRUST FOR THE STATES OF IOWA MISSOURI & IILINOIS',
#  'NAME_AMERICAN CONTRACTORS TRUST FOR THE STATES OF NEBRASKA KANSAS&OKLAHOMA',
#  'NAME_AMERICAN CONTRACTORS TRUST FOR THE STATES OF OHIO KENTUCKY & WEST VA',
#  'NAME_AMERICAN COUNCIL FOR MEDICINALLY ACTIVE PLANTS',
#  'NAME_AMERICAN COUNCIL OF ENGINEERING COMPANIES OF CALIFORNIA SANTA CLAR',
#  'NAME_AMERICAN CRIMINAL JUSTICE ASSOCIATION LAMBDA ALPHA EPSILON',
#  'NAME_AMERICAN CULINARY FEDERATION TREASURE COAST CHAPTER INC',
#  'NAME_AMERICAN DOG OWNERS FOR PROPER TRAINING INC',
#  'NAME_AMERICAN DREAM BRIGADE INC',
#  'NAME_AMERICAN DRUG UTILIZATIONS REVIEW SOCIETY',
#  'NAME_AMERICAN ESKIMO DOG CLUB OF AMERICA',
#  'NAME_AMERICAN FAMILY COALITION INC',
#  'NAME_AMERICAN FEDERATION OF GOVERNMENT EMPLOYEE',
#  'NAME_AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES',
#  'NAME_AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LOCAL 2886',
#  'NAME_AMERICAN FEDERATION OF LABOR & CONGRESS OF INDUSTRIAL ORGS',
#  'NAME_AMERICAN FEDERATION OF LABOR AND CONGRESS OF INDUSTRIAL ORGS',
#  'NAME_AMERICAN FEDERATION OF MUSICIANS OF THE US & CANADA',
#  'NAME_AMERICAN FEDERATION OF STATE COUNTY & MUNICIPAL EMPLOYEES',
#  'NAME_AMERICAN FEDERATION OF STATE COUNTY &MUNICIPAL EMPLOYEES',
#  'NAME_AMERICAN FEDERATION OF STATE COUNTY AND MUNICIPAL EMPLOYEESS',
#  'NAME_AMERICAN FEDERATION OF TEACHERS',
#  'NAME_AMERICAN FEDERATIONOF GOVERNMENT EMPLOYEES',
#  'NAME_AMERICAN FISHERIES SOCIETY',
#  'NAME_AMERICAN FOOTZONOLOGY PRACTITIONERS ASSOCIATION',
#  'NAME_AMERICAN FOUNDATION FOR ADDICTION RESEARCH',
#  'NAME_AMERICAN FOUNDATION FOR FURTHERINGIDEAS THAT REKINDLE THE MIRACLE OF',
#  'NAME_AMERICAN FOUNDATION FOR HUNGARIAN YOUTH AND CULTURE INC',
#  'NAME_AMERICAN FOUNDATION FOR TIBETAN CULTURAL PRESERVATION',
#  'NAME_AMERICAN FRIENDS OF PICCOLA ACCADEMIA DE MONTISI',
#  'NAME_AMERICAN FRIENDS OF THE OXFORD INTERNATIONAL BIOMEDICAL CENTRE',
#  'NAME_AMERICAN GAP FOUNDATION',
#  'NAME_AMERICAN GREEN CROSS',
#  'NAME_AMERICAN GROUP PSYCHOTHERAPY ASSOCIATION INC',
#  'NAME_AMERICAN HARP SOCIETY',
#  'NAME_AMERICAN HEART ASSOCIATION INC',
#  'NAME_AMERICAN HEROES LEGAL PROJECT INC',
#  'NAME_AMERICAN HIBISCUS',
#  'NAME_AMERICAN HINDI ACADEMY',
#  'NAME_AMERICAN HOUSING PRESERVATION CORPORATION',
#  'NAME_AMERICAN HUMANIST ASSOCIATION',
#  'NAME_AMERICAN IMMIGRATION LAWYERS ASSOCIATION',
#  'NAME_AMERICAN INDEPENDENT BUSINESS ALLIANCE',
#  'NAME_AMERICAN INDIAN ALASKA NATIVE TOURISM ASSOCIATION',
#  'NAME_AMERICAN INDIAN GRADUATE CENTER SCHOLARS',
#  'NAME_AMERICAN INDIAN HERITAGE DAY IN TEXAS',
#  'NAME_AMERICAN INSTITUTE FOR AVALANCHE RESEARCH AND EDUCATION INC',
#  'NAME_AMERICAN INSTITUTE OF GRAPHIC ARTS',
#  'NAME_AMERICAN INSTITUTE OF MINING METALLURGICAL AND PETROLEUM ENGINE',
#  'NAME_AMERICAN INTERNATIONAL RELIEF INC',
#  'NAME_AMERICAN IRIS SOCIETY',
#  'NAME_AMERICAN ISRAEL GAP YEAR ASSOCIATION',
#  'NAME_AMERICAN JUSTICE FOUNDATION INC',
#  'NAME_AMERICAN LEADERSHIP FORUM OF TACOMA PIERCE COUNTY CHAPTER',
#  'NAME_AMERICAN LEGION',
#  'NAME_AMERICAN LEGION 202 GATLINBURG INC',
#  'NAME_AMERICAN LEGION AUXILIARY',
#  'NAME_AMERICAN LEGION AUXILIARY BROWARD MEMORIAL UNIT 180 INC',
#  'NAME_AMERICAN LEGION AUXILIARY HICKMAN-PATTERSON POST 34',
#  'NAME_AMERICAN LEGION AUXILIARY LOGAN UNIT 7',
#  'NAME_AMERICAN LEGION AUXILIARY MESSINGER RAWLINGS BROS UNIT 76',
#  'NAME_AMERICAN LEGION AUXILIARY PASO DEL NORTE UNIT 58 DEPARTMENT OF TEXAS',
#  'NAME_AMERICAN LEGION AUXILIARY RIVIERA BEACH MEMORIAL UNIT 268',
#  'NAME_AMERICAN LEGION AUXILIARY SAN MARCO S UNIT 144',
#  'NAME_AMERICAN LEGION AUXILLARY',
#  'NAME_AMERICAN LEGION BAKER POST NO 41',
#  'NAME_AMERICAN LEGION HIGH SCHOOL RODEO OF WYOMING INC',
#  'NAME_AMERICAN LEGION NATIONAL CONVENTION CORPORATION OF HAWAII',
#  'NAME_AMERICAN LEGION POST',
#  'NAME_AMERICAN LEGION POST 0054 GRAND COUNTY',
#  'NAME_AMERICAN LEGION POST 198',
#  'NAME_AMERICAN LEGION POST 206 WHITE HOUSE TN INC',
#  'NAME_AMERICAN LEGION POST 81',
#  'NAME_AMERICAN MARKETING ASSOCIATION INC',
#  'NAME_AMERICAN MEN OF IMPACT INCORPORATED',
#  'NAME_AMERICAN MERCHANT MARINE VETERANS',
#  'NAME_AMERICAN MERCHANT MARINE VETERANS - SACRAMENTO VALLEY CHAPTER',
#  'NAME_AMERICAN MILITARY FAMILIES ACTION NETWORK CORPORATION',
#  'NAME_AMERICAN MOCK TRIAL ASSOCIATION',
#  'NAME_AMERICAN MOTHERS INC',
#  'NAME_AMERICAN MULTICULTURAL INSTITUTE INC',
#  'NAME_AMERICAN MULTIPLE ENDOCRINE NEOPLAS SUPPORT',
#  'NAME_AMERICAN MUSLIM INTERCULTURAL NETWORK',
#  'NAME_AMERICAN MUSLINS FOR EMERGENCY AND RELIEF',
#  'NAME_AMERICAN NEPHROLOGY NURSES ASSOCIATION',
#  'NAME_AMERICAN NIGHT WRITERS ASSOCIATION',
#  'NAME_AMERICAN OPPORTUNITY FOUNDATION',
#  'NAME_AMERICAN ORFF SCHULWERK ASSOCIATION',
#  'NAME_AMERICAN ORFF-SCHULWERK ASSOCIATION',
#  'NAME_AMERICAN ORGANIZATION OF NURSE EXECUTIVES',
#  'NAME_AMERICAN PAYROLL ASSOCIATION',
#  'NAME_AMERICAN PERFORMANCE SHOWCASE THEATER INC',
#  'NAME_AMERICAN POLISH TCZEW PARTNERSHIP INC',
#  'NAME_AMERICAN POSTAL WORKERS UNION',
#  'NAME_AMERICAN POSTAL WORKERS UNION BUILDING LLC',
#  'NAME_AMERICAN PROFESSIONAL WOUND CARE ASSOCIATION',
#  'NAME_AMERICAN PROGRESSIVE TELUGU ASSOCIATION',
#  'NAME_AMERICAN PSYCHIATRIC NURSES ASSOCIATION',
#  'NAME_AMERICAN PUBLIC WORKS ASSOCIATION OREGON CHAPTER SCHOLASTIC FND INC',
#  'NAME_AMERICAN RESEARCH CENTER IN EGYPT',
#  'NAME_AMERICAN RHODODENDRON SOCIETY',
#  'NAME_AMERICAN RIVER FUTBOL CLUB',
#  'NAME_AMERICAN RIVER WATERSHED INSTITUTE',
#  'NAME_AMERICAN ROSE SOCIETY',
#  'NAME_AMERICAN SADDLEBRED ASSOCIATION OF ARIZONA',
#  'NAME_AMERICAN SECONDARY SCHOOL',
#  'NAME_AMERICAN SELF-ESTEEM & POSITIVE IMAGE CORPORATION',
#  'NAME_AMERICAN SEWING GUILD INC',
#  'NAME_AMERICAN SHUDOKAN ASSOCIATION NORTHWEST SCHOLARSHIP FUND',
#  'NAME_AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI',
#  'NAME_AMERICAN SOCIETY OF ADDICTION MEDICINE',
#  'NAME_AMERICAN SOCIETY OF ADDICTION MEDICINE INC',
#  'NAME_AMERICAN SOCIETY OF CIVIL ENGINEERS',
#  'NAME_AMERICAN SOCIETY OF ENDOCRINE PHYSICIAN ASSISTANTS',
#  'NAME_AMERICAN SOCIETY OF HEATING REFRIGERATING & A-C ENGINEERS',
#  'NAME_AMERICAN SOCIETY OF LANDSCAPE ARCHITECTS',
#  'NAME_AMERICAN SOCIETY OF MILITARY COMPTROLLERS',
#  'NAME_AMERICAN SOCIETY OF PROFESIONAL ESTIMATORS CHAPTER 32',
#  'NAME_AMERICAN SOCIETY OF PROFESSIONAL ESTIMATORS ARIZONA CHAPTER 6',
#  'NAME_AMERICAN SPORTS KARATE BOOSTER CLUB',
#  'NAME_AMERICAN STAFFING ASSOCIATION',
#  'NAME_AMERICAN STRING TEACHERS ASSOCIATION INCORPORATED',
#  ...]

# %%
# Split our preprocessed data into our features and target arrays
X = df.drop('IS_SUCCESSFUL',axis=1)
y = df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
inputs = len(X.columns)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=9, activation="relu", input_dim=inputs))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=9, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=12, activation="tanh", input_dim=inputs))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=12, activation="tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 12)                235416
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                156
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 78
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 235,657
# Trainable params: 235,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
# EVALUATE 1ST PASS

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
from keras.callbacks import Callback

mc = tf.keras.callbacks.ModelCheckpoint('weights{epoch:08d}.h5',save_weights_only=True, period=5)

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, callbacks=[mc], epochs=10)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10
# 2022-03-27 21:52:46.260480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5211 - accuracy: 0.7364
# Epoch 2/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.1627 - accuracy: 0.9453
# Epoch 3/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.1074 - accuracy: 0.9612
# Epoch 4/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.1002 - accuracy: 0.9630
# Epoch 5/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0963 - accuracy: 0.9626
# Epoch 6/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0945 - accuracy: 0.9634
# Epoch 7/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0921 - accuracy: 0.9636
# Epoch 8/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0915 - accuracy: 0.9636
# Epoch 9/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0908 - accuracy: 0.9631
# Epoch 10/10
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0895 - accuracy: 0.9639

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 2s - loss: 0.5148 - accuracy: 0.7202
# Loss: 0.5147528648376465, Accuracy: 0.7202332019805908

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=6,
        max_value=18,
        step=6), activation=activation, input_dim=inputs))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 2)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=6,
            max_value=12,
            step=6),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import kerastuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=10,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
